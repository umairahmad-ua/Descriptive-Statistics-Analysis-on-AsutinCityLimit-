# %% [markdown]
# # **Umair Ahmad**
# # **21i-2081**

# %% [markdown]
# # **Assignment 1 of Stat. and Math. Methods for Data Science**
# We are required to break our analysis  into descriptive statistics to construct the answer

# %% [markdown]
# ## **Austin City Limits**
# Data is Known as the “Live Music Capital of the World,” Austin, Texas is also home to the longest-running music series in American television history, Austin City Limits.  This dataset includes data on a sample of musicians that performed live on the PBS television series Austin City Limits over the last 10 years.  Data on each artist include measures of commercial popularity, such as the number of social media followers on Twitter or Facebook, and their success in winning a Grammy Music Award.

# %% [markdown]
# # **Problem Statment**
#
# After the Grammy  award announcement. There was an unrest among the young artists. Some of the young artists complained that judges were inclined to give Grammy to old artists. we are required to accept or refute this claim by analyzing the  attached data set (AsutinCityLimit.csv)

# %% [markdown]
# # Data Reading for Analysis using R Function "read.csv"

# %%
#Data Reading
AustinCityLimits <- read.csv("/content/AustinCityLimits.csv", header=TRUE)
View(AustinCityLimits)
# Out:
#     Artist                         Year Month     Season Gender Age
# 1   Aimee Mann                     2008 November  fall   F      52
# 2   Alabama Shakes                 2013 February  winter F      24
# 3   Allen Toussaint                2009 January   winter M      75
# 4   Andrew Bird                    2009 October   fall   M      39
# 5   Arcade Fire                    2007 November  fall   F      33
# 6   Asleep at the Wheel            2009 November  fall   M      62
# 7   Avett Brothers                 2010 January   winter M      37
# 8   Band of Heathens               2009 November  fall   M      35
# 9   Beck                           2003 January   winter M      43
# 10  Bettye Lavette                 2008 October   fall   F      67
# 11  Bjork                          2007 October   fall   F      47
# 12  Black Joe Lewis                2012 January   winter M      49
# 13  Bloc Party                     2007 December  winter M      31
# 14  Blues Traveler                 2006 January   winter M      46
# 15  Bob Mould                      2013 February  winter M      52
# 16  Bon Iver                       2012 October   fall   M      32
# 17  Bonnie Rait                    2012 November  fall   F      63
# 18  Brad Paisley                   2008 January   winter M      40
# 19  Brandi Carlile                 2010 November  fall   F      32
# 20  Cafe Tacuba                    2006 January   winter M      45
# 21  Calexico                       2006 November  fall   M      47
# 22  Carrie Rodriguez               2008 October   fall   F      35
# 23  Cat Power                      2006 December  winter F      41
# 24  Cheap Trick                    2011 January   winter M      60
# 25  Coldplay                       2005 December  winter M      36
# 26  Crowded House                  2008 January   winter M      55
# 27  Dave Matthews Band             2009 October   fall   M      46
# 28  David Byrne                    2002 January   winter M      61
# 29  Death Cab for Cutie            2006 February  winter M      36
# 30  Delta Spirit                   2013 February  winter M      35
# ⋮   ⋮                              ⋮    ⋮         ⋮      ⋮      ⋮
# 87  Raphael Saadiq                 2012 January   winter M      47
# 88  Ray Davies                     2006 October   fall   M      69
# 89  Regina Spektor                 2007 September fall   F      33
# 90  Rodrigo y Gabriela             2013 January   winter M      36
# 91  Roky Erikson                   2008 January   winter M      65
# 92  Rosanne Cash                   2003 November  fall   F      58
# 93  Ryan Adams & the Cardinals     2006 January   winter M      38
# 94  Ryan Bingham                   2009 February  winter M      32
# 95  Sarah Jarosz                   2010 November  fall   F      22
# 96  Sarah McLachlan                2009 February  winter F      45
# 97  Sharon Jones and the Dap Kings 2008 November  fall   F      57
# 98  Social Distortion              2011 October   fall   M      51
# 99  Spoon                          2005 November  fall   M      42
# 100 Steve Earle                    2010 January   winter M      58
# 101 Steve Martin                   2010 November  fall   M      67
# 102 The Civil Wars                 2012 February  winter F      30
# 103 The Decemberists               2007 October   fall   M      38
# 104 The Gourds                     2006 December  winter M      45
# 105 The Polyphonic Spree           2004 November  fall   M      47
# 106 The Shins                      2012 October   fall   M      42
# 107 The Strokes                    2010 October   fall   M      34
# 108 The Swell Season               2009 January   winter F      43
# 109 Them Crooked Vultures          2010 February  winter M      44
# 110 Thievery Corporation           2008 November  fall   M      43
# 111 Tim McGraw                     2013 February  winter M      46
# 112 Tom Waits                      2011 December  winter M      63
# 113 Tune-Yards                     2013 February  winter F      34
# 114 Widespread Panic               2011 October   fall   M      51
# 115 Wilco                          2012 February  winter M      45
# 116 Willie Nelson                  2009 November  fall   M      80
#     Age.Group        Grammy Genre             BB.wk.top10 Twitter  Twitter.100k
# 1   Fifties or Older Y      Singer-Songwriter  0            101870  1
# 2   Twenties         N      Rock/Folk/Indie    1             73313  0
# 3   Fifties or Older N      Jazz/Blues        NA            308634  1
# 4   Thirties         N      Rock/Folk/Indie    1             56343  0
# 5   Thirties         Y      Rock/Folk/Indie    1            404439  1
# 6   Fifties or Older Y      Country            0              3326  0
# 7   Thirties         N      Rock/Folk/Indie    1            125758  1
# 8   Thirties         N      Rock/Folk/Indie   NA              8197  0
# 9   Forties          Y      Rock/Folk/Indie    1            158647  1
# 10  Fifties or Older N      Jazz/Blues         0               690  0
# 11  Forties          N      Singer-Songwriter  1            450096  1
# 12  Forties          N      Jazz/Blues         0             88689  0
# 13  Thirties         N      Rock/Folk/Indie    0            114703  1
# 14  Forties          Y      Rock/Folk/Indie    1             23244  0
# 15  Fifties or Older N      Rock/Folk/Indie    0             10033  0
# 16  Thirties         Y      Rock/Folk/Indie    1            367417  1
# 17  Fifties or Older Y      Country            1             18683  0
# 18  Forties          Y      Country            1           1787221  1
# 19  Thirties         N      Rock/Folk/Indie    1             20549  0
# 20  Forties          Y      Rock/Folk/Indie   NA            962232  1
# 21  Forties          N      Rock/Folk/Indie    0                NA NA
# 22  Thirties         N      Singer-Songwriter NA              1510  0
# 23  Forties          N      Singer-Songwriter  1             46659  0
# 24  Fifties or Older N      Rock/Folk/Indie    0             40682  0
# 25  Thirties         Y      Rock/Folk/Indie    1          10666531  1
# 26  Fifties or Older N      Rock/Folk/Indie    0              8981  0
# 27  Forties          Y      Rock/Folk/Indie    1            264123  1
# 28  Fifties or Older Y      Rock/Folk/Indie    0                NA NA
# 29  Thirties         N      Rock/Folk/Indie    1            112030  1
# 30  Thirties         N      Rock/Folk/Indie    0                NA NA
# ⋮   ⋮                ⋮      ⋮                 ⋮           ⋮        ⋮
# 87  Forties          Y      Jazz/Blues         0           127442   1
# 88  Fifties or Older N      Rock/Folk/Indie    0               NA  NA
# 89  Thirties         N      Singer-Songwriter  1           119847   1
# 90  Thirties         N      Rock/Folk/Indie    0            29538   0
# 91  Fifties or Older N      Rock/Folk/Indie    0               NA  NA
# 92  Fifties or Older N      Country            0            58994   0
# 93  Thirties         N      Rock/Folk/Indie    1           489105   1
# 94  Thirties         Y      Country            0            23929   0
# 95  Twenties         N      Singer-Songwriter  0             7359   0
# 96  Forties          Y      Singer-Songwriter  1           112023   1
# 97  Fifties or Older N      Jazz/Blues         0            12832   0
# 98  Fifties or Older N      Rock/Folk/Indie    1            59069   0
# 99  Forties          N      Rock/Folk/Indie    1            38534   0
# 100 Fifties or Older Y      Rock/Folk/Indie    0            23845   0
# 101 Fifties or Older Y      Rock/Folk/Indie    0          4093318   1
# 102 Thirties         Y      Rock/Folk/Indie    1           208376   1
# 103 Thirties         N      Rock/Folk/Indie    1           596450   1
# 104 Forties          N      Country           NA             1341   0
# 105 Forties          N      Rock/Folk/Indie    0             3284   0
# 106 Forties          N      Rock/Folk/Indie    1               NA  NA
# 107 Thirties         N      Rock/Folk/Indie    1           308637   1
# 108 Forties          N      Rock/Folk/Indie    0            18796   0
# 109 Forties          Y      Rock/Folk/Indie    0            80620   0
# 110 Forties          N      Rock/Folk/Indie    0            19659   0
# 111 Forties          Y      Country            1           859774   1
# 112 Fifties or Older N      Singer-Songwriter  1           202327   1
# 113 Thirties         N      Jazz/Blues        NA               NA  NA
# 114 Fifties or Older N      Rock/Folk/Indie    0            35150   0
# 115 Forties          Y      Rock/Folk/Indie    1           118222   1
# 116 Fifties or Older Y      Country            0           267839   1
#     Facebook Facebook.100k
# 1     113576 1
# 2     298278 1
# 3      10721 0
# 4     318313 1
# 5    1711685 1
# 6      27321 0
# 7     563505 1
# 8      18955 0
# 9    1381051 1
# 10      1715 0
# 11   2754505 1
# 12     24866 0
# 13   1129035 1
# 14    164048 1
# 15     30525 0
# 16   1626215 1
# 17    357770 1
# 18   5429471 1
# 19    223872 1
# 20    497452 1
# 21    119103 1
# 22      8888 0
# 23    279644 1
# 24    529395 1
# 25  28243550 1
# 26    135089 1
# 27   3005593 1
# 28    113310 1
# 29   2156318 1
# 30     65395 0
# ⋮   ⋮        ⋮
# 87   419342  1
# 88    32734  0
# 89  1590500  1
# 90   315706  1
# 91    22888  0
# 92    27302  0
# 93   344108  1
# 94    95638  0
# 95    21676  0
# 96  1094819  1
# 97    96819  0
# 98   902626  1
# 99   343303  1
# 100  189080  1
# 101  357886  1
# 102  425487  1
# 103  546394  1
# 104   10878  0
# 105   30714  0
# 106  619052  1
# 107 3547961  1
# 108  115831  1
# 109  556553  1
# 110  439903  1
# 111 5236511  1
# 112 1818741  1
# 113   86010  0
# 114  303223  1
# 115  569817  1
# 116 2023718  1

# %% [markdown]
# # Distribution visualization of Grammy with classes "Y" and "N"

# %%
#Plot the Grammy values
gtab = table(AustinCityLimits$Grammy)
barplot(gtab)
# Out:
# plot without title

# %% [markdown]
# # Distribution visualization of Age_Group with classes
# # "Twenties" , "Thirties" , "Forties" and "Fifties or Older"

# %%
gtab = table(AustinCityLimits$Age.Group)
barplot(gtab)
# Out:
# plot without title

# %% [markdown]
# # **Contingency table to show the marginal distribution for each variable**
# # **"Grammy ","Age Group"**
# ## Contingency table is a type of table in a matrix format that displays the frequency distribution of the variables.

# %%
#Tabel function to genrate Contengency Table
gtab=table(AustinCityLimits$Grammy, AustinCityLimits$Age.Group)
# addmargin will add the sum column and rows
addmargins(gtab)
# Out:
#
#       Fifties or Older Forties Thirties Twenties Sum
#   N   17               13      28        9        67
#   Y   15               17      12        5        49
#   Sum 32               30      40       14       116

# %% [markdown]
# # **Contingency Table of Conditional Distribution for the given data in the "AustinCityLimits"**

# %%
# Prop.tabel will generate the probabilties 
gtab2=prop.table(table(AustinCityLimits$Grammy, AustinCityLimits$Age.Group))
addmargins(gtab2)
# Out:
#
#       Fifties or Older Forties   Thirties  Twenties   Sum
#   N   0.1465517        0.1120690 0.2413793 0.07758621 0.5775862
#   Y   0.1293103        0.1465517 0.1034483 0.04310345 0.4224138
#   Sum 0.2758621        0.2586207 0.3448276 0.12068966 1.0000000

# %% [markdown]
# # Computing the Probabilties each class of Grammy in each Age Group

# %%
prob_gtab2= prop.table(prop.table(gtab2), 2)
addmargins(prob_gtab2,1)
# Out:
#
#       Fifties or Older Forties   Thirties Twenties
#   N   0.53125          0.4333333 0.7      0.6428571
#   Y   0.46875          0.5666667 0.3      0.3571429
#   Sum 1.00000          1.0000000 1.0      1.0000000

# %% [markdown]
# # Barplot for distribution of each class of Grammy in each Age Group

# %%
#Relative Frequency stacked bar chart Using parameter ‘beside=T’
barplot(prob_gtab2, legend=TRUE,beside=TRUE)
# Out:
# plot without title

# %% [markdown]
# # **The Question we want to answer:**
# ## Is there a relationship between the Grammy award winning with age group?

# %% [markdown]
#  As we can clearly see that in the barplot there is a correlation between grammy-winning and age groups. The bar of age 30 and older are much higher as compare to the young artists so by visualizing we can say that there is correlation between Grammy and age group.
#
#
# 1.   For artists, age 30 or older are considered old artists
# 2.   For age less than 29 considered as young artists
#
# # However, we can also statistically prove that they are correlated by proving this relation
# Relationship between two categorical variables
# # **Marginal probability != Conditional Probabilty**

# %% [markdown]
# # **Steps**
#
#
# 1.   From the contingency table decide which variable is best for to be the outcome (dependent variable)
# 2.   Just like in correlation when we need to determine what the outcome variable is.
# In our example lets use **Age Group** as a dependente variable
# 3. Determine the margin distribution from the outcome variable of interest
# 4. If P(A|B) = P(A) then there is no relationship. If we fail to prove that P(A|B) = P(A) then we have a relationship

# %% [markdown]
# # Row Percentages
#
# These are the conditional distributions of columns by rows. In that case the columns are the Dependent Variable

# %%
 # Marginal distribution of Row P(A)
  MarginalRowPercentage = margin.table(gtab, 1)/nrow(AustinCityLimits)
  MarginalRowPercentage
# Out:
#         N         Y
# 0.5775862 0.4224138

# %% [markdown]
# Determine the conditional distribution for the variable of interest

# %%
# Conditional probabilty of Row P(A/B)
ColumnPercentage = prop.table(gtab,2)
ColumnPercentage
# Out:
#
#     Fifties or Older   Forties  Thirties  Twenties
#   N        0.5312500 0.4333333 0.7000000 0.6428571
#   Y        0.4687500 0.5666667 0.3000000 0.3571429

# %% [markdown]
# Compare these distributions probabilites. To discover if the is a relationship see wheter of not the marginal distribution holde when compared to the conditional distribuition of the dependant variable.

# %%
  # Puting together the two tables 
  
  ColumnMarginalPercentage = cbind(ColumnPercentage,MarginalRowPercentage)
  ColumnMarginalPercentage
# Out:
#   Fifties or Older Forties   Thirties Twenties  MarginalRowPercentage
# N 0.53125          0.4333333 0.7      0.6428571 0.5775862
# Y 0.46875          0.5666667 0.3      0.3571429 0.4224138

# %% [markdown]
# # **Final Remarks**
# # **The Claim is True**
# Just looking within the Table Age groups we can see that condition probability of columns does not match out marginal probabilty of Grammy winner. We can see that the likelyhood of A old artist to win grammy is more than young artist.
# P(A|B) != P(A) there is a relationship.  we prove that P(A|B) != P(A)
# # **So there is absolutely a relationship between Age Group and Grammy winner**

# %% [markdown]
# # **Assignment 2**
# # **Problem Statement**
# Denmark is a high-income country, and Belarus is a medium-income country of about the same size. Find the best-ﬁtting model for internet usage in each country since 1990 (Use WorldBankData.csv). Then answer the question: Does income level have an impact on the speed with which a country adopts use of the internet?

# %% [markdown]
# # Determine the best-fitting model (exponential or logistic) for internet usage in each country from 1990 onward.

# %% [markdown]
# # Loading the WorldBankData.csv

# %%
#reading the worldbankdata 
WorldBankData <- read.csv("/content/WorldBankData.csv", header=TRUE)
View(WorldBankData)
# Out:
#       Country  Country.Code year Region                    IncomeGroup
# 1     Aruba    ABW          1960 Latin America & Caribbean High income
# 2     Aruba    ABW          1961 Latin America & Caribbean High income
# 3     Aruba    ABW          1962 Latin America & Caribbean High income
# 4     Aruba    ABW          1963 Latin America & Caribbean High income
# 5     Aruba    ABW          1964 Latin America & Caribbean High income
# 6     Aruba    ABW          1965 Latin America & Caribbean High income
# 7     Aruba    ABW          1966 Latin America & Caribbean High income
# 8     Aruba    ABW          1967 Latin America & Caribbean High income
# 9     Aruba    ABW          1968 Latin America & Caribbean High income
# 10    Aruba    ABW          1969 Latin America & Caribbean High income
# 11    Aruba    ABW          1970 Latin America & Caribbean High income
# 12    Aruba    ABW          1971 Latin America & Caribbean High income
# 13    Aruba    ABW          1972 Latin America & Caribbean High income
# 14    Aruba    ABW          1973 Latin America & Caribbean High income
# 15    Aruba    ABW          1974 Latin America & Caribbean High income
# 16    Aruba    ABW          1975 Latin America & Caribbean High income
# 17    Aruba    ABW          1976 Latin America & Caribbean High income
# 18    Aruba    ABW          1977 Latin America & Caribbean High income
# 19    Aruba    ABW          1978 Latin America & Caribbean High income
# 20    Aruba    ABW          1979 Latin America & Caribbean High income
# 21    Aruba    ABW          1980 Latin America & Caribbean High income
# 22    Aruba    ABW          1981 Latin America & Caribbean High income
# 23    Aruba    ABW          1982 Latin America & Caribbean High income
# 24    Aruba    ABW          1983 Latin America & Caribbean High income
# 25    Aruba    ABW          1984 Latin America & Caribbean High income
# 26    Aruba    ABW          1985 Latin America & Caribbean High income
# 27    Aruba    ABW          1986 Latin America & Caribbean High income
# 28    Aruba    ABW          1987 Latin America & Caribbean High income
# 29    Aruba    ABW          1988 Latin America & Caribbean High income
# 30    Aruba    ABW          1989 Latin America & Caribbean High income
# ⋮     ⋮        ⋮            ⋮    ⋮                         ⋮
# 13274 Zimbabwe ZWE          1983 Sub-Saharan Africa        Low income
# 13275 Zimbabwe ZWE          1984 Sub-Saharan Africa        Low income
# 13276 Zimbabwe ZWE          1985 Sub-Saharan Africa        Low income
# 13277 Zimbabwe ZWE          1986 Sub-Saharan Africa        Low income
# 13278 Zimbabwe ZWE          1987 Sub-Saharan Africa        Low income
# 13279 Zimbabwe ZWE          1988 Sub-Saharan Africa        Low income
# 13280 Zimbabwe ZWE          1989 Sub-Saharan Africa        Low income
# 13281 Zimbabwe ZWE          1990 Sub-Saharan Africa        Low income
# 13282 Zimbabwe ZWE          1991 Sub-Saharan Africa        Low income
# 13283 Zimbabwe ZWE          1992 Sub-Saharan Africa        Low income
# 13284 Zimbabwe ZWE          1993 Sub-Saharan Africa        Low income
# 13285 Zimbabwe ZWE          1994 Sub-Saharan Africa        Low income
# 13286 Zimbabwe ZWE          1995 Sub-Saharan Africa        Low income
# 13287 Zimbabwe ZWE          1996 Sub-Saharan Africa        Low income
# 13288 Zimbabwe ZWE          1997 Sub-Saharan Africa        Low income
# 13289 Zimbabwe ZWE          1998 Sub-Saharan Africa        Low income
# 13290 Zimbabwe ZWE          1999 Sub-Saharan Africa        Low income
# 13291 Zimbabwe ZWE          2000 Sub-Saharan Africa        Low income
# 13292 Zimbabwe ZWE          2001 Sub-Saharan Africa        Low income
# 13293 Zimbabwe ZWE          2002 Sub-Saharan Africa        Low income
# 13294 Zimbabwe ZWE          2003 Sub-Saharan Africa        Low income
# 13295 Zimbabwe ZWE          2004 Sub-Saharan Africa        Low income
# 13296 Zimbabwe ZWE          2005 Sub-Saharan Africa        Low income
# 13297 Zimbabwe ZWE          2006 Sub-Saharan Africa        Low income
# 13298 Zimbabwe ZWE          2007 Sub-Saharan Africa        Low income
# 13299 Zimbabwe ZWE          2008 Sub-Saharan Africa        Low income
# 13300 Zimbabwe ZWE          2009 Sub-Saharan Africa        Low income
# 13301 Zimbabwe ZWE          2010 Sub-Saharan Africa        Low income
# 13302 Zimbabwe ZWE          2011 Sub-Saharan Africa        Low income
# 13303 Zimbabwe ZWE          2012 Sub-Saharan Africa        Low income
#       population rural.population hiv.cases san.access motor.vehicles gas.price
# 1     54208      26683            NA        NA         NA             NA
# 2     55435      27296            NA        NA         NA             NA
# 3     56226      27694            NA        NA         NA             NA
# 4     56697      27934            NA        NA         NA             NA
# 5     57029      28107            NA        NA         NA             NA
# 6     57360      28278            NA        NA         NA             NA
# 7     57712      28461            NA        NA         NA             NA
# 8     58049      28636            NA        NA         NA             NA
# 9     58385      28810            NA        NA         NA             NA
# 10    58724      28987            NA        NA         NA             NA
# 11    59065      29164            NA        NA         NA             NA
# 21         NA       0           NA
# 22         NA       0           NA
# 23         NA       0           NA
# 24         NA       0           NA
# 25         NA       0           NA
# 26         NA       0           NA
# 27    179.683       0           NA
# 28    447.374       0           NA
# 29    612.389       0           NA
# 30    649.059       0           NA
# ⋮     ⋮            ⋮            ⋮
# 13274 10461.951           0          NA
# 13275  9922.902           0          NA
# 13276 10263.933           0          NA
# 13277 13127.860           0          NA
# 13278 15240.052           0          NA
# 13279 16101.797           0          NA
# 13280 16186.138           0          NA
# 13281 15504.076           0           0
# 13282 15823.105           0          NA
# 13283 16901.203           0          NA
# 13284 16208.140           0          NA
# 13285 17645.604           0         199
# 13286 15130.042           0         894
# 13287 14994.363           0        1989
# 13288 14407.643        5734        3985
# 13289 14253.629       19000        9985
# 13290 15834.106      174000       20023
# 13291 13886.929      266441       50194
# 13292 12563.142      314002      100675
# 13293 11932.418      338779      504923
# 13294 10626.966      363651      810418
# 13295  9926.569      425745      833177
# 13296 10773.646      647110     1018878
# 13297 10344.607      849146     1245944
# 13298 10212.595     1225654     1382307
# 13299  8148.074     1654721     1457381
# 13300  8734.794     3991000     1464181
# 13301  9427.857     7700000     1503852
# 13302        NA     9200000     2097322
# 13303        NA    12613935     2345596

# %% [markdown]
# # Preprocessing and filtering the Data(Removing NA values and getting Denmark, Belarus data)

# %%
#Filtering the Data 
Data<-WorldBankData[WorldBankData$year>=1990,]
Denmark_Data<-Data[Data$Country=="Denmark",]
Belarus_Data<-Data[Data$Country=="Belarus",]
#Removing the NA values
Belarus_Data<-Belarus_Data[!is.na(Belarus_Data$internet.users),]

# %%
Belarus_Data
# Out:
#      Country Country.Code year Region                IncomeGroup
# 1250 Belarus BLR          1990 Europe & Central Asia Upper middle income
# 1254 Belarus BLR          1994 Europe & Central Asia Upper middle income
# 1255 Belarus BLR          1995 Europe & Central Asia Upper middle income
# 1256 Belarus BLR          1996 Europe & Central Asia Upper middle income
# 1257 Belarus BLR          1997 Europe & Central Asia Upper middle income
# 1258 Belarus BLR          1998 Europe & Central Asia Upper middle income
# 1259 Belarus BLR          1999 Europe & Central Asia Upper middle income
# 1260 Belarus BLR          2000 Europe & Central Asia Upper middle income
# 1261 Belarus BLR          2001 Europe & Central Asia Upper middle income
# 1262 Belarus BLR          2002 Europe & Central Asia Upper middle income
# 1266 Belarus BLR          2006 Europe & Central Asia Upper middle income
# 1267 Belarus BLR          2007 Europe & Central Asia Upper middle income
# 1268 Belarus BLR          2008 Europe & Central Asia Upper middle income
# 1269 Belarus BLR          2009 Europe & Central Asia Upper middle income
# 1270 Belarus BLR          2010 Europe & Central Asia Upper middle income
# 1271 Belarus BLR          2011 Europe & Central Asia Upper middle income
# 1272 Belarus BLR          2012 Europe & Central Asia Upper middle income
#      population rural.population hiv.cases san.access motor.vehicles gas.price
# 1250 10189000   3466196          10189     9699876         NA          NA
# 1254 10227000   3319991          10227          NA         NA          NA
# 1255 10194000   3269624          10194     9697050         NA          NA
# 1256 10160000   3217123          10160          NA         NA          NA
# 1257 10117000   3162089          10117          NA         NA          NA
# 1258 10069000   3105864          10069          NA         NA        0.34
# 1259 10035000   3054293          10035          NA         NA          NA
# 1260 10005000   3004201          10005     9496543    1886994        0.55
# 1261  9928000   2933803           9928          NA    1867522          NA
# 1262  9865000   2868209          19730          NA    1934603        0.50
# 1266  9604000   2611693          28812          NA    2405840        0.79
# 1267  9560000   2556497          28680          NA    2562384          NA
# 1268  9528000   2504854          38112          NA    2705365        1.33
# 1269  9507000   2456343          38028          NA    2870674          NA
# 1270  9490000   2409036          37960     8959599    3042665        1.08
# 1271  9473000   2366204          37892          NA    3190094          NA
# 1272  9464000   2325475          37856     8927301         NA        0.88
#      co2.emission mobile.users internet.users
# 1250       NA            0           1
# 1254 65914.32         1725          50
# 1255 62118.98         5900         298
# 1256 60157.14         6550        2977
# 1257 59519.08         8164        4959
# 1258 57597.57        12141        7438
# 1259 55819.07        23458       49661
# 1260 53468.53        49469      186133
# 1261 52595.78       138438      426965
# 1262 52390.43       463200      883013
# 1266 61829.29      5949865     1555848
# 1267 60281.81      6941580     1883320
# 1268 62815.71      8104353     2191440
# 1269 60292.81      9667099     2607770
# 1270 62221.66     10331735     3017820
# 1271       NA     10720486     3751308
# 1272       NA     10743336     4439184

# %% [markdown]
# # Plotting the year and internet.users relations and try to visualize the trend of Belarus Data

# %%
plot(Belarus_Data$year,Belarus_Data$internet.users)
# Out:
# plot without title

# %% [markdown]
# # Plotting the year and internet.users relations and try to visualize the trend of Denmark Data

# %%
plot(Denmark_Data$year,Denmark_Data$internet.users)
# Out:
# plot without title

# %% [markdown]
# # **Just by looking at the plotted graph between year and internet.users behavior we can clearly claim Belarus can fit the Exponetinal Model well and Denmark seems to show logistic behaviour so it will fit the Logistic model well**

# %% [markdown]
# # However, we can also statistically prove that which model is best by calculating R square for each and the maximum of RSqaure value can prove this is the best model.

# %% [markdown]
# # Fitting Linear Model for Belarus Data

# %%
#lm function which autmatically fit the data by taking dependent and independent values
LinearModel.fit = lm(internet.users~year, data=Belarus_Data)
#Summary function returns all the basis details
summary(LinearModel.fit)
# Out:
# Call:
# lm(formula = internet.users ~ year, data = Belarus_Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -628450 -397987 -195887  208610 1231208
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -408343501   44819655  -9.111 1.68e-07 ***
# year            204579      22387   9.138 1.61e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 600300 on 15 degrees of freedom
# Multiple R-squared:  0.8477,	Adjusted R-squared:  0.8376
# F-statistic: 83.51 on 1 and 15 DF,  p-value: 1.613e-07

# %% [markdown]
# # Plotting Residuals Fits

# %%
plot(LinearModel.fit, las = 1)      # Residuals, Fitted, ...
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # Fitting ExponentialModel for Berlarus Data

# %%
require(graphics)
ExponentialModel.fit = lm(log(internet.users)~year, data=Belarus_Data)
summary(ExponentialModel.fit)
# Out:
# Call:
# lm(formula = log(internet.users) ~ year, data = Belarus_Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.5014 -1.1232  0.2866  0.7347  2.6646
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.244e+03  1.354e+02  -9.194 1.49e-07 ***
# year         6.271e-01  6.761e-02   9.276 1.33e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.813 on 15 degrees of freedom
# Multiple R-squared:  0.8515,	Adjusted R-squared:  0.8416
# F-statistic: 86.04 on 1 and 15 DF,  p-value: 1.331e-07

# %% [markdown]
# # Plotting Residuals Fits

# %%
plot(ExponentialModel.fit, las = 1)      # Residuals, Fitted, ...
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # Fitting Logistic Model for Berlarus Data

# %%
Belarus_Data$internet.users=factor(Belarus_Data$internet.users)
logistic_model <- glm(internet.users~year , 
                      data = Belarus_Data, 
                      family = "binomial")
summary(logistic_model)
# Out:
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = internet.users ~ year, family = "binomial", data = Belarus_Data)
#
# Deviance Residuals:
#        Min          1Q      Median          3Q         Max
# -2.248e-05   2.110e-08   2.110e-08   2.110e-08   3.069e-05
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -2.170e+04  2.357e+07  -0.001    0.999
# year         1.089e+01  1.183e+04   0.001    0.999
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 7.6064e+00  on 16  degrees of freedom
# Residual deviance: 1.4470e-09  on 15  degrees of freedom
# AIC: 4
#
# Number of Fisher Scoring iterations: 25

# %% [markdown]
# # Plotting Residuals Fits

# %%
plot(logistic_model)
# Out:
# Plot with title “”
# Plot with title “”
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# “NaNs produced”
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# “NaNs produced”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # As we can clearly see the maximum R sqaure value for Belarus is produced by the **ExponentialModel** with
# 1. Residual standard error: 1.813 on 15 degrees of freedom
# 2. Multiple R-squared:  0.8515,	Adjusted R-squared:  0.8416
# 3. F-statistic: 86.04 on 1 and 15 DF,  p-value: 1.331e-07

# %% [markdown]
# # **Producing Results for Denmark Data**

# %% [markdown]
# # Fitting Linear Model for Denmark Data

# %%
LinearModel.fit = lm(internet.users~year, data=Denmark_Data)
summary(LinearModel.fit)
# Out:
# Call:
# lm(formula = internet.users ~ year, data = Denmark_Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -766856 -431447 -147249  515307  956208
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -594026677   35858402  -16.57 1.56e-13 ***
# year            298143      17920   16.64 1.44e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 570100 on 21 degrees of freedom
# Multiple R-squared:  0.9295,	Adjusted R-squared:  0.9261
# F-statistic: 276.8 on 1 and 21 DF,  p-value: 1.436e-13

# %% [markdown]
# # Plotting Residuals Fits

# %%
plot(LinearModel.fit)  # Residuals, Fitted, ...
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # Fitting ExponentialModel for Denmark Data

# %%
ExponentialModel.fit = lm(log(internet.users)~year, data=Denmark_Data)
summary(ExponentialModel.fit)
# Out:
# Call:
# lm(formula = log(internet.users) ~ year, data = Denmark_Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.7925 -0.9167  0.2333  0.9444  1.2805
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -589.47350   64.95540  -9.075 1.03e-08 ***
# year           0.30140    0.03246   9.285 6.99e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.033 on 21 degrees of freedom
# Multiple R-squared:  0.8041,	Adjusted R-squared:  0.7948
# F-statistic: 86.21 on 1 and 21 DF,  p-value: 6.989e-09

# %% [markdown]
# # Plotting Residuals Fits

# %%
plot(ExponentialModel.fit, las = 1) # Residuals, Fitted, ...
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # Fitting Logistic Model on Denmark Data

# %%
Denmark_Data$internet.users=factor(Denmark_Data$internet.users)

logistic_model <- glm(internet.users~year , 
                      data = Denmark_Data, 
                      family = "binomial")
summary(logistic_model)
# Out:
# Warning message:
# “glm.fit: algorithm did not converge”
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = internet.users ~ year, family = "binomial", data = Denmark_Data)
#
# Deviance Residuals:
#       Min         1Q     Median         3Q        Max
# -8.12e-05   2.10e-08   2.10e-08   2.10e-08   9.87e-05
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept) -7.697e+04  2.723e+07  -0.003    0.998
# year         3.867e+01  1.368e+04   0.003    0.998
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 8.2269e+00  on 22  degrees of freedom
# Residual deviance: 1.6335e-08  on 21  degrees of freedom
# AIC: 4
#
# Number of Fisher Scoring iterations: 25

# %% [markdown]
# # Plotting Residuals Fits

# %%
plot(logistic_model)
# Out:
# Plot with title “”
# Plot with title “”
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# “NaNs produced”
# Warning message in sqrt(crit * p * (1 - hh)/hh):
# “NaNs produced”
# Plot with title “”
# Plot with title “”

# %% [markdown]
# # As we can clearly see the best score and low error for Denmark is produced by the **Logistic Model** with
# 1. Null deviance: 8.2269e+00  on 22  degrees of freedom
# 2. Residual deviance: 1.6335e-08  on 21  degrees of freedom

# %% [markdown]
# # **Analysing the 2nd part of assignment 2**
# Does income level have an impact on the speed with which a country adopts use of the internet

# %% [markdown]
# # To answer this Predicting years when internet users will be 80% of population
# 1. for internet usage in each country from 1990 onward.
# 2. Using the best-fitting model for each country,
# 3. determine which country shows a faster adoption rate of the internet.

# %%
#joining datasets :
WorldBankData <- read.csv("/content/WorldBankData.csv", header=TRUE)
WorldBankData<-WorldBankData[!is.na(WorldBankData$internet.users),]
View(WorldBankData)
#data_tbl=rbind.data.frame(Denmark_Data,Belarus_Data)
# Out:
#       Country     Country.Code year Region
# 31    Aruba       ABW          1990 Latin America & Caribbean
# 37    Aruba       ABW          1996 Latin America & Caribbean
# 40    Aruba       ABW          1999 Latin America & Caribbean
# 41    Aruba       ABW          2000 Latin America & Caribbean
# 42    Aruba       ABW          2001 Latin America & Caribbean
# 43    Aruba       ABW          2002 Latin America & Caribbean
# 44    Aruba       ABW          2003 Latin America & Caribbean
# 45    Aruba       ABW          2004 Latin America & Caribbean
# 46    Aruba       ABW          2005 Latin America & Caribbean
# 47    Aruba       ABW          2006 Latin America & Caribbean
# 48    Aruba       ABW          2007 Latin America & Caribbean
# 49    Aruba       ABW          2008 Latin America & Caribbean
# 50    Aruba       ABW          2009 Latin America & Caribbean
# 51    Aruba       ABW          2010 Latin America & Caribbean
# 52    Aruba       ABW          2011 Latin America & Caribbean
# 53    Aruba       ABW          2012 Latin America & Caribbean
# 50        NA           NA      2295.542       128000       58822
# 51        NA           NA      2321.211       131800       62990
# 52        NA           NA            NA           NA       70333
# 53        NA           NA            NA       135000       75764
# 84        NA           NA      2676.910            0           0
# 95     75195           NA       645.392            0        1008
# 96    122751         0.34       359.366        25000        1013
# 97    239706           NA       583.053       200000       20317
# 98    265575         0.53       733.400       600000       25414
# 99    336949           NA      1015.759      1200000      304334
# 100   400191         0.68      1338.455      2520366      540083
# 101   592519           NA      1991.181      4668096      500636
# 102   648782         1.05      3927.357      7898909      497392
# 103   723901           NA      6523.593     10500000      983641
# 104   794372         1.15      8236.082     13000000     1135912
# 105   852406           NA            NA     17558265     1455274
# 106       NA         1.28            NA     18000000     1626793
# 137       NA           NA      4429.736            0           0
# ⋮     ⋮              ⋮         ⋮            ⋮            ⋮
# 13241      NA          NA       2101.191      241000      106819
# 13242      NA        1.10       2130.527      464354      225007
# 13243      NA          NA       2273.540      949559      327097
# 13244      NA        1.31       2225.869     1663328      490105
# 13245  212028          NA       1653.817     2639026      589738
# 13246  266148        1.70       1844.501     3539003      691337
# 13247      NA          NA       2156.196     4406682      809259
# 13248      NA        1.66       2427.554     5446991     1321698
# 13249      NA          NA             NA     8164553     1567887
# 13250      NA        1.48             NA    10524676     1895662
# 13281      NA          NA      15504.076           0           0
# 13285      NA          NA      17645.604           0         199
# 13286      NA        0.38      15130.042           0         894
# 13287      NA          NA      14994.363           0        1989
# 13288      NA          NA      14407.643        5734        3985
# 13289      NA        0.26      14253.629       19000        9985
# 13290      NA          NA      15834.106      174000       20023
# 13291      NA        0.85      13886.929      266441       50194
# 13292      NA          NA      12563.142      314002      100675
# 13293      NA        0.05      11932.418      338779      504923
# 13294      NA          NA      10626.966      363651      810418
# 13295      NA        0.61       9926.569      425745      833177
# 13296      NA          NA      10773.646      647110     1018878
# 13297      NA          NA      10344.607      849146     1245944
# 13298 1445877          NA      10212.595     1225654     1382307
# 13299      NA        1.30       8148.074     1654721     1457381
# 13300      NA          NA       8734.794     3991000     1464181
# 13301      NA        1.29       9427.857     7700000     1503852
# 13302      NA          NA             NA     9200000     2097322
# 13303      NA        1.52             NA    12613935     2345596

# %%
#label encoding of class IncomeGroup as Correlation test only take numeric data
classes <- c("Low income","Lower middle income","Upper middle income","High income")
data <- factor(WorldBankData$IncomeGroup, levels = classes)
income_group=as.numeric(data)

# %%
#Pearson correlation test
#Correlation test between income group and internet_users variables:
res <- cor.test(income_group, as.numeric(WorldBankData$internet.users), method = "pearson")
res
# Out:
# 	Pearson's product-moment correlation
#
# data:  income_group and as.numeric(WorldBankData$internet.users)
# t = 6.7665, df = 4020, p-value = 1.51e-11
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.07545895 0.13657666
# sample estimates:
#      cor
# 0.106118

# %%
# Extract the correlation coefficient
res$estimate
# Out:
#      cor
# 0.106118

# %% [markdown]
# # **By looking at the correlation coefficient the value is very close to zero 0.1(low correlation) it means income level does not have much impact on the speed of with which a country adopts use of the internet**
